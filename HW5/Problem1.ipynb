# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisfinan/GenAI/blob/main/HW5/Problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Chris Finan
# > HW5
#
# >11/22/24

# %% [markdown]
# #Description
# Text Generation Using LSTM on Project Gutenberg Training Data:
# * In this project you will develop an LSTM (Long Short-Term Memory) model to generate text.
# * By training the model on various works, you will try to produce coherent and stylistically relevant text based on seed phrases (prompts).
# * To improve the model's performance, you will explore the use of multiple training data, additional LSTM layers, and other optimizations.
# * The quantity and quality of training data are crucial for achieving meaningful text generation; a larger and more diverse dataset allows the model to better capture the nuances and patterns of written text.
# * I will be creating 2 different LSTM models and using them to generate text based on 5 different Shakespeare stories.

# %%
import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses

# %% [markdown]
# ## 0. Parameters <a name="parameters"></a>

# %%
VOCAB_SIZE = 20000
MAX_LEN = 200
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %% [markdown]
# ## 1. Load the data <a name="load"></a>

# %%
import requests

# List of URLs for additional texts (e.g., different Shakespeare plays)
urls = [
  "https://www.gutenberg.org/files/1041/1041-0.txt",  # The Sonnets
  "https://www.gutenberg.org/files/1112/1112-0.txt" ,  # Romeo and Juliet
  "https://www.gutenberg.org/cache/epub/1531/pg1531.txt" , # Othello
  "https://www.gutenberg.org/cache/epub/1533/pg1533.txt",   # Macbeth
  "https://www.gutenberg.org/cache/epub/1514/pg1514.txt" # A Midsummer Night's Dream
]

# Initialize an empty string to hold all text
all_text = ""

# Download each text file and append to all_text
for url in urls:
  response = requests.get(url)
  text = response.text
  all_text += text + "\n\n"  # Separate texts by newlines

# Save combined text to a single file
with open("combined_shakespeare.txt", "w", encoding="utf-8") as file:
  file.write(all_text)

# %%
# Function to clean a single story
def clean_story(text):
    # After checking all the links, these statements start/end the stories:
    start_marker = r"\*\*\* START OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*"
    end_marker = r"\*\*\* END OF THE PROJECT GUTENBERG EBOOK.*?\*\*\*"

    # Keep only the text after the start marker
    start_match = re.search(start_marker, text, flags=re.DOTALL)
    if start_match:
        text = text[start_match.end():]  # Trim everything before the marker

    # Remove everything after the end marker
    end_match = re.search(end_marker, text, flags=re.DOTALL)
    if end_match:
        text = text[:end_match.start()]  # Trim everything after the marker

    # Convert text to lowercase
    text = text.lower()

    # Replace multiple spaces, newlines, and tabs with a single space
    text = re.sub(r"\s+", " ", text).strip()

    return text

# Initialize an empty string to hold all cleaned text
cleaned_text = ""

# Download each text file, clean, and append to cleaned_text
for url in urls:
    response = requests.get(url)
    text = response.text
    cleaned = clean_story(text)
    cleaned_text += cleaned + "\n\n"  # Separate texts by newlines

# There is too much punctuation in weird places because the texts are mostly plays - need to remove to output better results
cleaned_text = cleaned_text.translate(str.maketrans("", "", string.punctuation))
cleaned_text = re.sub(r"[{}‘’“”\"]".format(re.escape(string.punctuation)), "", cleaned_text)

# Save the cleaned combined text to a single file - I used this to verify the text was cleaned of noise
with open("cleaned_shakespeare.txt", "w", encoding="utf-8") as file:
    file.write(cleaned_text)

# Preview the first 1000 characters of cleaned text
print(cleaned_text[:1000])
# Out:
# the sonnets by william shakespeare i from fairest creatures we desire increase that thereby beautys rose might never die but as the riper should by time decease his tender heir might bear his memory but thou contracted to thine own bright eyes feedst thy lights flame with selfsubstantial fuel making a famine where abundance lies thyself thy foe to thy sweet self too cruel thou that art now the worlds fresh ornament and only herald to the gaudy spring within thine own bud buriest thy content and tender churl makst waste in niggarding pity the world or else this glutton be to eat the worlds due by the grave and thee ii when forty winters shall besiege thy brow and dig deep trenches in thy beautys field thy youths proud livery so gazed on now will be a tatterd weed of small worth held then being asked where all thy beauty lies where all the treasure of thy lusty days to say within thine own deep sunken eyes were an alleating shame and thriftless praise how much more praise deservd thy bea

# %% [markdown]
# ## 2. Tokenise the data

# %%
# There is a lot of punctuation and they were basically treated as normal words, so I removed them above
# I left this statement here because I was getting errors when I removed it
def pad_punctuation(s):
    # Pad punctuation to treat them as separate tokens
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s

# Pad punctuation in the cleaned text
cleaned_text = [pad_punctuation(cleaned_text)]

# %%
sequence_length = 50
sequences = []
# Access the string within the list using cleaned_text[0]
for i in range(0, len(cleaned_text[0].split()) - sequence_length):
    seq = cleaned_text[0].split()[i: i + sequence_length]
    sequences.append(" ".join(seq))

# Need to split into 2 different variables for data:
x_data = [seq[:-1] for seq in sequences]  # All but the last token
y_data = [seq[-1] for seq in sequences]  # Only the last token

# %%
# Convert to a Tensorflow Dataset
text_ds = tf.data.Dataset.from_tensor_slices((x_data, y_data))

# Shuffle and batch
text_ds = text_ds.shuffle(1000).batch(BATCH_SIZE, drop_remainder=True)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# %%
# Adapt the layer to the training set
vectorize_layer.adapt(x_data)
vocab = vectorize_layer.get_vocabulary()

# %%
# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: the
# 3: and
# 4: i
# 5: to
# 6: of
# 7: a
# 8: my
# 9: in

# %% [markdown]
# ## 3. Create the Training Set

# %%
# Create the training set of recipes and the same text shifted by one word
def prepare_inputs(text, _):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]  # All but the last token
    y = tokenized_sentences[:, 1:]  # Shifted sequence (the next token)
    return x, y[:, 0]  # Keep only the first token for y

train_ds = text_ds.map(prepare_inputs)

train_ds = train_ds.shuffle(buffer_size=1000)

# %% [markdown]
# ## 4. Build the LSTM <a name="build"></a>

# %%
# Only 1 LSTM layer, so return_sequences is false
inputs = layers.Input(shape=(sequence_length,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(N_UNITS, return_sequences=False)(x)
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_2 (Embedding)              │ (None, 50, 100)             │       2,000,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 128)                 │         117,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20000)               │       2,580,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,697,248 (17.92 MB)
#  Trainable params: 4,697,248 (17.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 5. Train the LSTM <a name="train"></a>

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Had to make quite a few changes to this class, especially the sample_from and generate functions
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10, sequence_length=100):
        self.index_to_word = index_to_word
        self.word_to_index = {word: index for index, word in enumerate(index_to_word)}
        self.sequence_length = sequence_length

    def sample_from(self, probs, temperature, top_k=10, top_p=0.9):
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)

        if top_k > 0:
            top_k_indices = np.argsort(probs)[-top_k:]
            filtered_probs = np.zeros_like(probs)
            filtered_probs[top_k_indices] = probs[top_k_indices]
            probs = filtered_probs / np.sum(filtered_probs)

        elif top_p > 0:
            sorted_indices = np.argsort(probs)[::-1]
            cumulative_probs = np.cumsum(probs[sorted_indices])
            cutoff = np.argmax(cumulative_probs > top_p)
            valid_indices = sorted_indices[:cutoff + 1]
            filtered_probs = np.zeros_like(probs)
            filtered_probs[valid_indices] = probs[valid_indices]
            probs = filtered_probs / np.sum(filtered_probs)

        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [self.word_to_index.get(x, 1) for x in start_prompt.split()]
        sample_token = None
        info = []

        while len(start_tokens) < max_tokens and (sample_token is None or sample_token != 0):
            x = np.array([start_tokens[-self.sequence_length:]])
            if len(x[0]) < self.sequence_length:
                x = np.pad(x, [(0, 0), (self.sequence_length - len(x[0]), 0)], constant_values=0)

            y = self.model.predict(x, verbose=0)
            probs = y[0]

            for token in start_tokens[-15:]:  # Increase the lookback
                probs[token] *= 0.5  # Apply penalty for repetition
            probs = probs / np.sum(probs)

            sample_token, probs = self.sample_from(probs, temperature)
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)

            if 0 <= sample_token < len(self.index_to_word):
                start_prompt += " " + self.index_to_word[sample_token]
            else:
                start_prompt += " <UNK>"
                break

        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("Out out brief candle", max_tokens=100, temperature=1.0)

# %%
# Tokenize starting prompt

text_generator = TextGenerator(vocab)

# %%
lstm.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[text_generator],
)
# Out:
# Epoch 1/25
# 3322/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.0088
# generated text:
# Out out brief candle cunning norways and on iron on peascod much pox hems span fated necessary misheathed heal enfetterd essence span isles heal span isles taket yee necessary postposthaste unguarded suggestion unguarded certainly shorter isles coold outcast moraler span imports banish saluted taket acknown taket yee suggestion yee taket circled unguarded flaming certainly jesses sayling owdst reuels unguarded assassination taket greeting—speak peerless taket cabind screw fearing burst unguarded listning benedecite certainly span appetites suggestion greeting—speak suggestion predecessors saluted disasters unguarded taket welltuned breechd unguarded certainly afloat greeting—speak suggestion her—lie gouts suggestion suggestion suggestion predecessors suggestion taket greeting—speak using disasters
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 3.0088
# Epoch 2/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9852
# generated text:
# Out out brief candle ever to at at to and he he do do painful certainly span votarist isles throw— jesses necessary heal enfetterd reward enfetterd distinguish unguarded suggestion jesses taket span imports cumberland—that moraler wedlock unguarded taket yee suggestion haggard saluted mutinie undivulgd golgotha listning cabind unguarded suggestion her—lie flaming taket fearing jesses slope afloat predecessors taket afloat predecessors listning predecessors listning afloat taket cabind fearing certainly jesses suggestion greeting—speak reuels cumberland—that pardond taket circled anywhere— taket greeting—speak suggestion taket essence cabind screw burst saluted suggestion welltuned golgotha taket fearing greeting—speak listning greeting—speak suggestion greeting—speak suggestion certainly unguarded egg
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 49s 14ms/step - loss: 2.9852
# Epoch 3/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9640
# generated text:
# Out out brief candle mistearmd in when and he he he do do sennights span isles unguarded experience enfetterd span reward cunning that fated strooken votarist suggestion jesses heal shorter haggard saluted his—what redoubled informs mutinie taket yee listning votarist taket span span circled outrun suggestion haggard present—get fearing haggard redoubled saluted disasters gouts certainly greeting—speak listning cabind greeting—speak listning fearing greeting—speak parricide listning span haggard redoubled cumberland—that welltuned jesses outrun taket yee taket greeting—speak taket fearing greeting—speak suggestion taket roderigos using anywhere— present—get strooken screw shoes unguarded saluted saluted wade her—lie disasters present—get greeting—speak suggestion taket cabind taket his—what
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 83s 15ms/step - loss: 2.9640
# Epoch 4/25
# 3321/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.9013
# generated text:
# Out out brief candle i in that mistearmd he he do he do do do her—lie unguarded bathe unguarded heal enfetterd isles heal acknown isles supervisor span span isles taket bell—diablo haggard outrun flaming thralls flaming golgotha taket predecessors reuels listning afloat predecessors unguarded listning isles her—lie assassination supervisor haggard outrun present—get limbeck taket fearing taket isles listning bell—diablo thralls flaming taket sir—o listning cabind haggard present—get fearing screw isles unguarded outrun suggestion taket taket predecessors anywhere— saluted say—this suggestion taket greeting—speak skirr outrun present—get welltuned predecessors saluted disasters cumberland—that her—lie wade certainly span cabind certainly cabind fearing greeting—speak outrun
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 2.9013
# Epoch 5/25
# 3321/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8822
# generated text:
# Out out brief candle perceivst liking and slanderer bathe certainly certainly clip pitfall certainly fearing lxxxvii overcome egg his—what scannd using undivulgd taket his—what egg beares but—dost informs me— predecessors certainly cabind span certainly span cabind but—dost certainly lims taket logicke disasters saluted informs wade welltuned taket span cabind appetites silly span votarist taket his—what egg greeting—speak disasters disasters saluted informs saluted outrun suggestion suggestion taket his—what mutinie egg appetites taket span his—what egg screw certainly his—what disasters present—get greeting—speak egg screw unguarded skirr anywhere— marshallst taket span his—what saluted egg welltuned breechd greeting—speak outrun disasters wade taket span his—what
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 49s 15ms/step - loss: 2.8822
# Epoch 6/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8368
# generated text:
# Out out brief candle bell—diablo and and and pants span span acknown bell—diablo supervisor span haggard supervisor span span isles silly throw— taket cabind supervisor logicke coold jesses but—dost coold bell—diablo cabind supervisor desdemona— cumberland—that predecessors cumberland—that thralls oerleaps coold taket span span span greeting—speak certainly bell—diablo thralls logicke logicke disasters taket span haggard disasters present—get span span cabind span span cabind span owdst logicke logicke marshallst mutinie trifled undivulgd haggard taket bell—diablo taket span certainly certainly circled thralls egg appetites marshallst outrun roofd afloat dunnest thralls coold haggard coold begrimd listning greeting—speak assassination anywhere— disasters disasters yew span cabind
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 47s 14ms/step - loss: 2.8368
# Epoch 7/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8094
# generated text:
# Out out brief candle bell—diablo and pants discerne span span celebration celebration slanderer desdemona— certainly readiness bathe span haggard vesture celebration but—dost certainly falcon appetites but—dost taket bell—diablo span isles but—dost marshallst taket falcon span span cabind vesture disasters gouts dooms span cabind cabind haggard coold span cabind appetites but—dost but—dost undivulgd span span vesture taket cabind supervisor owdst taket span greeting—speak oerleaps supervisor haggard but—dost taket span nonpareil taket cabind taket isles disasters present—get span span span laying cabind appetites greeneyd fraught span span cabind cabind thralls vulnerable saluted yew span nonpareil golgotha taket breechd cabind taket cabind taket
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 83s 14ms/step - loss: 2.8094
# Epoch 8/25
# 3321/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7745
# generated text:
# Out out brief candle bell—diablo and discerne haggard sennights span span slanderer certainly safeties supervisor span bell—diablo desdemona— coold supervisor span cabind supervisor celebration taket haggard supervisor span span span cabind span span cabind disasters silly falcon span predecessors but—dost taket cabind haggard but—dost them—list undivulgd jesses thralls marshallst taket span span cabind span cabind jesses coold span supervisor span cabind vesture jesses but—dost taket deficient span laying bell—diablo taket span cabind span predecessors disasters marshallst them—list oerleaps instruction span thralls coold haggard assassination marshallst outrun taket span cabind span cabind span supervisor haggard coold appetites but—dost anywhere— memorize nonpareil
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 2.7745
# Epoch 9/25
# 3322/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.7438
# generated text:
# Out out brief candle bell—diablo and supervisor span deficient isles experience span span span span dooms dooms haggard bathe supervisor vesture jesses blackest laying haggard but—dost memorize span cabind cabind span span span cabind span span cabind if—i thralls memorize dilatory span greeting—speak thralls undivulgd supervisor logicke marshallst logicke listning appetites greeneyd span span haggard but—dost supervisor span laying dunnest cabind supervisor dunnest experience span cabind span bell—diablo span span laying greeting—speak napkins logicke taket span cabind haggard them—list supervisor span appetites trifled widowed instruction span banish listning dunnest thralls present—get laying cabind haggard thralls coold haggard anywhere— assassination undivulgd
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 2.7438
# Epoch 10/25
# 3320/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7400
# generated text:
# Out out brief candle bell—diablo bell—diablo greeting—speak poppy bell—diablo span span haggard haggard supervisor haggard dooms falcon span vesture supervisor span haggard but—dost undivulgd dilatory isles however cabind falcon span span haggard certainly span falcon haggard memorize appetites but—dost taket bell—diablo shrill coold supervisor vesture banish coold span cabind span dunnest haggard marshallst logicke disasters supervisor span haggard but—dost undivulgd laying appetites logicke memorize messes but—dost greeneyd span vesture banish disasters them—list disasters memorize span span haggard logicke logicke instruction supervisor taket dunnest dunnest greeting—speak undivulgd laying nonpareil isles greeneyd dunnest thralls disasters assassination greeneyd span cabind haggard disasters anywhere—
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - loss: 2.7400
# Epoch 11/25
# 3322/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7195
# generated text:
# Out out brief candle ene on amended which then bristled on ensnard on isles he he he he do do that span span ensnard span laying fated usage isles widowed memorize celebration listning isles celebration houshould marshallst bellonas marshallst assassination undivulgd dunnest span supervisor jesses disasters instruction span span thralls trifled instruction span span cabind appetites undivulgd laying cabind span span cabind span jesses logicke supervisor distaste supervisor span span falcon span span greeneyd cabind span cabind span distaste dilatory roderigos supervisor logicke instruction span cabind cabind banish thralls thralls thralls coold dunnest dunnest isles assassination instruction span appetites undivulgd
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 2.7194
# Epoch 12/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6902
# generated text:
# Out out brief candle bell—diablo and idleness experience span span acknown isles supervisor span span span span span acknown isles supervisor dilatory cabind banish undivulgd distaste distaste greeneyd acknown isles greeneyd haggard memorize span span span span acknown ensnard shrill greeneyd span celebration logicke memorize span appetites distaste haggard logicke trifled disasters coold span span dilatory span bell—diablo distaste span span cabind span acknown span span cabind celebration greeneyd hams logicke logicke marshallst mutinie supervisor span span distaste span span strooken span cabind distaste distaste dunnest span jesses disasters undivulgd isles assassination marshallst peerless thralls disasters instruction span span span
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 2.6902
# Epoch 13/25
# 3322/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6657
# generated text:
# Out out brief candle bell—diablo and discerne pants supervisor span span span isles dilatory distaste greeneyd span cabind haggard ruins distaste supervisor jesses logicke supervisor span greeneyd greeneyd celebration greeneyd span isles logicke undivulgd span span dunnest celebration greeneyd snorting but—dost greeneyd span greeneyd span cabind cabind hams undivulgd fraught isles greeneyd easier span span foams isles instruction span span greeting—speak greeneyd distaste supervisor logicke disasters peerless undivulgd celebration marshallst logicke greeneyd span span cabind cabind span greeneyd appetites upons span cabind assassination instruction pontic disasters referred instruction span experience supervisor dunnest span isles yew dunnest isles tuggd listning span
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 85s 25ms/step - loss: 2.6657
# Epoch 14/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6286
# generated text:
# Out out brief candle haggard blackest celebration experience pontic haggard vesture skillet celebration supervisor span span span span span acknown cabind dilatory laying greeting—speak instruction jesses instruction jesses supervisor distaste jesses instruction span span distaste span span span span dilatory cabind greeneyd dunnest distaste jesses undivulgd jesses experience reconciliation pontic instruction span span dunnest span span celebration instruction pontic instruction span cabind cabind distaste jesses greeneyd distaste jesses logicke referred supervisor span pontic disasters referred instruction span span dunnest reconciliation span peerless disasters feat disasters instruction dunnest cabind shifted yew span cabind supervisor jesses disasters referred coold span banish assassination
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 105s 14ms/step - loss: 2.6286
# Epoch 15/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6164
# generated text:
# Out out brief candle shadowes dido haggard blackest experience span span bell—diablo celebration celebration supervisor jesses supervisor jesses but—dost greeneyd span falcon span virtuously dilatory isles supervisor span span cabind if—i logicke memorize jesses greeneyd celebration greeneyd span haggard greeneyd span span dunnest cabind span cabind supervisor logicke coold span messes venice—hence span haggard instruction span haggard but—dost greeneyd jesses logicke memorize supervisor supervisor cabind supervisor logicke referred iustly span celebration instruction dunnest fraught isles instruction dunnest jesses feat instruction shifted assassination disasters instruction span span pontic greeneyd peerless instruction celebration present—get span banish instruction span cabind jesses instruction isles
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 82s 14ms/step - loss: 2.6164
# Epoch 16/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.6221
# generated text:
# Out out brief candle twisted occasions twisted flurtgils poppy dido acknown haggard lowre span celebration extravagant blackest celebration supervisor span if—i supervisor jesses but—dost feat celebration iustly span isles greeneyd span span cabind distaste celebration logicke marshallst shadowes haggard greeneyd celebration greeneyd supervisor jesses logicke feat coold span banish iustly span span celebration instruction celebration but—dost memorize pontic logicke feat shadowes isles greeneyd span fraught celebration logicke iustly span celebration disasters trifled marshallst shadowes pontic feat feat assassination instruction shifted anointed fraught isles instruction fraught pontic instruction dunnest celebration instruction strooken isles assassination referred assassination instruction span span isles instruction
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 83s 15ms/step - loss: 2.6221
# Epoch 17/25
# 3321/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6116
# generated text:
# Out out brief candle gowne bell—diablo here your dooms isles supervisor celebration distaste span jesses greeneyd span isles greeneyd distaste span span cabind span reconciliation isles supervisor celebration greeneyd haggard hells celebration greeneyd dunnest span isles greeneyd span span isles assassination iustly bell—diablo supervisor celebration instruction celebration memorize jesses memorize jesses trifled shadowes span logicke disasters shadowes span foams reconciliation isles assassination instruction celebration supervisor celebration iustly distaste jesses marshallst yew span greeting—speak assassination endall—here trifled trifled feat disasters instruction isles greeneyd horned isles assassination peerless instruction owdst instruction celebration assassination instruction dunnest pontic disasters tuggd yew span fraught span
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 80s 14ms/step - loss: 2.6116
# Epoch 18/25
# 3322/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.6025
# generated text:
# Out out brief candle twisted shadowes twisted twisted shadowes dido hairbreadth reeks shadowes twisted shadowes bell—diablo dido twisted twisted twisted iustly dido that angelicall shadowes dido twisted twisted feat verity iustly span isles assassination instruction cabind span span span isles assassination instruction dunnest pontic assassination feat peerless dunnest celebration tuggd assassination equivocate assassination undivulgd dunnest span span span distaste pontic assassination instruction returned jesses tuggd disasters instruction cabind isles undivulgd dunnest span span isles assassination instruction cabind pontic assassination assassination feat assassination assassination tuggd thralls disasters greeneyd dunnest span isles instruction shifted anointed dunnest celebration assassination instruction strooken pontic disasters
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 2.6025
# Epoch 19/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5801
# generated text:
# Out out brief candle bell—diablo here and and coniured ho—lieutenant—sir—montano—sir— twisted twisted distaste twisted celebration celebration celebration celebration experience celebration distaste pontic distaste experience indign besort span span bell—diablo horned span bell—diablo pontic experience isles greeneyd distaste distaste supervisor jesses scan pontic greeneyd pontic supervisor celebration instruction distaste bell—diablo span jesses tuggd auld begant distaste distaste distaste jesses scan span span pontic supervisor distaste pontic undivulgd returned pontic instruction jesses instruction dunnest pontic instruction isles horned span span bell—diablo distaste pontic undivulgd dunnest pontic instruction jesses undivulgd isles greeneyd horned span distaste span jesses instruction strooken distaste fraught jesses feat
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 49s 15ms/step - loss: 2.5801
# Epoch 20/25
# 3321/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5717
# generated text:
# Out out brief candle bell—diablo here and hells twisted coniured and discerne distaste twisted twisted distaste celebration pieces dewe distaste fuller fuller fuller pontic experience span enfetterd experience indign distaste pontic distaste span indign besort jesses instruction pontic scan bell—diablo supervisor isles boisterous jesses trifled instruction shifted assassination greeneyd dunnest span span celebration horned span pontic tuggd instruction pontic assassination referred instruction jesses tuggd disasters greeneyd dunnest span distaste isles horned span pontic assassination greeneyd dunnest pontic instruction returned isles instruction jesses undivulgd fraught distaste distaste jesses tuggd horned span span bell—diablo dunnest celebration assassination instruction franticmad horned span span
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 2.5717
# Epoch 21/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5391
# generated text:
# Out out brief candle bell—diablo the delves the wincke he he he he he he he he he he he distaste twisted supervisor pontic distaste bell—diablo celebration experience bell—diablo celebration greeneyd span jesses distaste fuller span horned span bell—diablo isles distaste distaste distaste jesses scan pontic assassination assassination auld scan pontic applause jesses assassination instruction returned horned span span span jesses assassination undivulgd dunnest pontic isles instruction jesses referred assassination instruction shifted assassination instruction shifted reuels instruction horned span span span isles assassination greeneyd shifted scan span pontic dunnest pontic assassination referred assassination instruction horned span isles instruction now—whats returned
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 49s 15ms/step - loss: 2.5391
# Epoch 22/25
# 3321/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.5202
# generated text:
# Out out brief candle deficient deficient ottoman experience deficient fuller isles distaste celebration twisted twisted twisted twisted twisted twisted twisted more distaste span celebration venice—hence pontic supervisor execute dilatory indign painful nephews twisted iustly deficient isles twisted twisted boisterous span span bell—diablo bell—diablo pontic scan distaste horned span isles instruction horned bell—diablo isles tuggd assassination scan isles assassination miscalld returned scan horned reconciliation span foams bell—diablo jesses auld instruction franticmad dunnest span horned span pontic assassination undivulgd returned reconciliation span shifted assassination instruction bell—diablo jesses tuggd instruction jesses tuggd instruction dunnest pontic auld miscalld isles reuels marshallst iustly franticmad horned
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 50s 15ms/step - loss: 2.5201
# Epoch 23/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.4526
# generated text:
# Out out brief candle bell—diablo your twisted coniured supervisor celebration distaste span pontic besort fuller pontic dilatory span isles skillet dewe besort celebration painful distaste celebration twisted twisted twisted twisted marshallst reckless gazing scuruie spoil gazing execute indign calamitie sir—o returned jesses besort span pontic scan pontic scan horned bell—diablo isles assassination instruction returned propriety span bell—diablo dunnest distaste returned reconciliation pontic horned horned pontic marshallst assassination instruction jesses scan twisted auld scan franticmad shifted assassination assassination iustly horned horned fear—how isles instruction propriety span bell—diablo bell—diablo revel indign scan fear—how isles scan twisted reuels instruction shifted miscalld franticmad horned
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 80s 14ms/step - loss: 2.4526
# Epoch 24/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.3932
# generated text:
# Out out brief candle fuller pontic shadowes fear—how span twisted iustly span twisted venice—hence distaste celebration twisted twisted iustly pontic greeneyd span dilatory opression boisterous distaste fear—how isles execute span bell—diablo jesses besort distaste pontic experience span isles boisterous bell—diablo pontic scan franticmad propriety isles instruction returned dunnest fear—how span jesses horned twisted assassination gazeth returned returned returned pontic scan twisted horned sir—o returned returned propriety isles horned unmoved miscalld jesses instruction dunnest span returned shifted assassination auld sir—o returned now—whats circled pontic scan bell—diablo requite instruction franticmad sir—o isles instruction horned indign miscalld franticmad returned shifted iustly franticmad returned
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 83s 15ms/step - loss: 2.3932
# Epoch 25/25
# 3321/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4246
# generated text:
# Out out brief candle conveniences isles instruction franticmad returned pontic scan twisted miscalld unmoved miscalld twisted miscalld unmoved miscalld twisted reuels miscalld twisted reuels miscalld unmoved scan twisted gazeth shifted assassination gazeth isles miscalld pontic miscalld pontic miscalld franticmad horned propriety isles miscalld twisted scan twisted reuels miscalld twisted gazeth shifted scan franticmad tuggd instruction unmoved miscalld unmoved miscalld unmoved miscalld twisted reuels miscalld twisted gazeth pontic them—list reuels miscalld twisted instruction unmoved reuels miscalld twisted reuels instruction unmoved miscalld twisted miscalld unmoved miscalld unmoved scan twisted franticmad shifted miscalld unmoved gazeth hotly scan twisted gazeth hotly miscalld twisted miscalld
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 49s 15ms/step - loss: 4.4256

# %% [markdown]
# After running 25 epochs, you can clearly see that the text is in Shakespearian English. Unfortunately though, there isn't much coherence the further you go down the line. There is also an interesting repetition for some words, like 'span' 4 times in a row at epoch 25. Epoch 3 also repeats 'haggard' several times. I spent several hours trying to debug the TextGenerator class and this seemed to be the best generation after multiple run-throughs.

# %% [markdown]
# ## 6. Generate text using the LSTM

# %%
# For some reason I got an error on only one block of code with this, so I had to slightly change
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            # Check if index is within vocab bounds before accessing
            if i < len(vocab):
                print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
            else:
                print(f"Unknown token ID: {i} (out of vocabulary) \t{np.round(100*p,2)}%")  # Indicate out-of-vocabulary tokens
        print("--------\n")

# %% [markdown]
# This first quote is from Macbeth and the generation doesn't really make sense, but it is also only 10 words. The word 'iustly' seems like a mistake or a typo - could be 'justly.' Then this one would kind of make sense, but 99% for that word is weird. Using 0.5 for temperature seems balanced and it made decent decisions overall.
# > "By the pricking of my thumbs something wicked this way comes"

# %%
info = text_generator.generate(
    "By the pricking of my thumbs", max_tokens=10, temperature=0.5
)

print_probs(info, vocab)
# Out:
# generated text:
# By the pricking of my thumbs fear—how wear iustly twisted
#
#
# PROMPT: By the pricking of my thumbs
# most:   	60.24%
# fear—how:   	28.81%
# propriety:   	2.53%
# conveniences:   	2.44%
# languishes:   	2.32%
# --------
#
#
# PROMPT: By the pricking of my thumbs fear—how
# returned:   	35.23%
# perspective:   	19.77%
# shifted:   	12.82%
# grows:   	9.62%
# fear—how:   	9.6%
# --------
#
#
# PROMPT: By the pricking of my thumbs fear—how wear
# iustly:   	99.99%
# more:   	0.01%
# miscalld:   	0.0%
# from:   	0.0%
# gazeth:   	0.0%
# --------
#
#
# PROMPT: By the pricking of my thumbs fear—how wear iustly
# shifted:   	27.09%
# twisted:   	24.81%
# span:   	14.98%
# unmoved:   	9.26%
# fear—how:   	5.59%
# --------

# %% [markdown]
# This one was really weird and didn't make sense. After perspective, it looks like all coherence is thrown out the window. A lower temperature should make the safer plays and ideally sound more coherent, but there is a problem here. I tried to penalize repeated words, but that fell through on some occaisions. Here the word 'he' is generated 12 times in a row at 100%! This was also the one that originally created an error for a token out of bounds. Maybe in one of the plays it repeats 'he' to mimic a laugh, but there is clearly something wrong here.
# > "But, soft! what light through yonder window breaks?
# It is the east, and Juliet is the sun."

# %%
info = text_generator.generate(
    "What light through yonder window breaks", max_tokens=20, temperature=0.2
)

print_probs(info, vocab)
# Out:
# generated text:
# What light through yonder window breaks chancd perspective he he he he he he he he he he he he
#
#
# PROMPT: What light through yonder window breaks
# chancd:   	94.63%
# franticmad:   	3.02%
# returned:   	2.24%
# bell—diablo:   	0.09%
# shifted:   	0.01%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd
# perspective:   	100.0%
# clip:   	0.0%
# circled:   	0.0%
# lacking:   	0.0%
# bonds:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective
# he:   	100.0%
# Unknown token ID: 19999 (out of vocabulary) 	0.0%
# solemnities:   	0.0%
# sorrie:   	0.0%
# sores:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he
# he:   	100.0%
# instruction:   	0.0%
# more:   	0.0%
# fees:   	0.0%
# iustly:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he
# he:   	100.0%
# instruction:   	0.0%
# scan:   	0.0%
# horned:   	0.0%
# fees:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he
# he:   	100.0%
# instruction:   	0.0%
# horned:   	0.0%
# scan:   	0.0%
# miscalld:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he
# he:   	100.0%
# instruction:   	0.0%
# horned:   	0.0%
# scan:   	0.0%
# miscalld:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he he
# he:   	100.0%
# instruction:   	0.0%
# scan:   	0.0%
# horned:   	0.0%
# miscalld:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he he he
# he:   	100.0%
# instruction:   	0.0%
# miscalld:   	0.0%
# scan:   	0.0%
# horned:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he he he he
# he:   	100.0%
# miscalld:   	0.0%
# instruction:   	0.0%
# scan:   	0.0%
# iustly:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he he he he he
# he:   	100.0%
# instruction:   	0.0%
# miscalld:   	0.0%
# scan:   	0.0%
# iustly:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he he he he he he
# he:   	99.39%
# instruction:   	0.61%
# miscalld:   	0.0%
# scan:   	0.0%
# horned:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he he he he he he he
# he:   	89.76%
# instruction:   	10.24%
# miscalld:   	0.0%
# scan:   	0.0%
# horned:   	0.0%
# --------
#
#
# PROMPT: What light through yonder window breaks chancd perspective he he he he he he he he he he he
# he:   	99.99%
# instruction:   	0.01%
# miscalld:   	0.0%
# scan:   	0.0%
# horned:   	0.0%
# --------

# %% [markdown]
# This one has an interesting word choice altogether and repeats miscalld and twisted many times. With a higher temperature of 1.0, the structure and word choice seems more random, however these words are repeated too many times. Words like miscalld are disproportionately higher percentage, but are not 100% like the last one.
# > "Deny thy father and refuse thy name.
# Or, if thou wilt not, be but sworn my love,
# And I'll no longer be a Capulet."

# %%
info = text_generator.generate(
    "Deny thy father and refuse thy name", max_tokens=40, temperature=1.0
)
print_probs(info, vocab)
# Out:
# generated text:
# Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan twisted miscalld twisted yew span shifted miscalld
#
#
# PROMPT: Deny thy father and refuse thy name
# fear—how:   	79.33%
# pontic:   	4.35%
# sorted:   	3.36%
# bell—diablo:   	3.18%
# returned:   	2.47%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how
# bell—diablo:   	30.45%
# horned:   	10.66%
# shifted:   	10.36%
# isles:   	10.05%
# sir—o:   	8.79%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted
# instruction:   	47.88%
# iustly:   	25.75%
# them—list:   	5.78%
# assassination:   	3.89%
# marshallst:   	3.77%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction
# franticmad:   	30.22%
# miscalld:   	24.09%
# reuels:   	15.34%
# sir—o:   	12.29%
# now—whats:   	4.22%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o
# isles:   	39.08%
# returned:   	23.23%
# pontic:   	11.36%
# dunnest:   	8.94%
# shifted:   	3.96%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic
# miscalld:   	58.76%
# assassination:   	9.95%
# scan:   	8.46%
# instruction:   	7.08%
# gazeth:   	4.58%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels
# miscalld:   	78.03%
# gazeth:   	5.0%
# instruction:   	4.16%
# iustly:   	3.11%
# assassination:   	2.47%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination
# miscalld:   	67.96%
# scan:   	11.93%
# instruction:   	6.91%
# gazeth:   	5.29%
# enfeebled:   	1.89%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan
# twisted:   	81.65%
# franticmad:   	11.47%
# unmoved:   	2.56%
# circled:   	1.44%
# sir—o:   	0.7%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted
# miscalld:   	87.66%
# reuels:   	5.51%
# gazeth:   	3.16%
# enfeebled:   	2.28%
# fearing:   	0.39%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld
# twisted:   	69.05%
# unmoved:   	16.24%
# franticmad:   	7.89%
# hotly:   	1.52%
# returned:   	1.4%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted
# miscalld:   	59.16%
# reuels:   	19.44%
# gazeth:   	7.07%
# iustly:   	3.9%
# enfeebled:   	2.83%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld
# twisted:   	42.1%
# unmoved:   	38.67%
# franticmad:   	9.78%
# returned:   	1.97%
# hotly:   	1.86%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved
# miscalld:   	74.47%
# gazeth:   	9.29%
# reuels:   	9.19%
# scan:   	3.72%
# enfeebled:   	0.75%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld
# twisted:   	63.57%
# franticmad:   	14.7%
# unmoved:   	12.12%
# returned:   	2.78%
# hotly:   	1.68%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted
# miscalld:   	36.52%
# reuels:   	34.68%
# enfeebled:   	8.31%
# gazeth:   	6.03%
# iustly:   	5.58%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld
# twisted:   	47.34%
# unmoved:   	21.05%
# franticmad:   	18.76%
# returned:   	2.87%
# hotly:   	2.43%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted
# reuels:   	39.38%
# miscalld:   	15.93%
# gazeth:   	14.78%
# iustly:   	9.36%
# enfeebled:   	5.98%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly
# franticmad:   	38.52%
# now—whats:   	23.21%
# shifted:   	10.78%
# unmoved:   	9.42%
# bell—diablo:   	4.22%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how
# isles:   	22.01%
# shifted:   	17.38%
# unmoved:   	16.13%
# returned:   	11.51%
# horned:   	10.56%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted
# miscalld:   	21.11%
# scan:   	19.3%
# instruction:   	13.01%
# reuels:   	12.89%
# gazeth:   	11.43%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth
# returned:   	66.35%
# hotly:   	10.46%
# franticmad:   	8.45%
# sir—o:   	4.42%
# now—whats:   	2.96%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned
# dunnest:   	20.69%
# returned:   	18.68%
# isles:   	13.72%
# instruction:   	10.91%
# franticmad:   	8.51%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned
# pontic:   	26.52%
# isles:   	25.78%
# dunnest:   	14.75%
# horned:   	6.36%
# returned:   	5.8%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest
# isles:   	37.55%
# unmoved:   	17.46%
# pontic:   	8.38%
# shifted:   	7.6%
# horned:   	6.42%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles
# miscalld:   	42.77%
# scan:   	25.21%
# instruction:   	10.32%
# reuels:   	8.6%
# auld:   	2.9%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan
# twisted:   	73.82%
# unmoved:   	18.19%
# franticmad:   	4.78%
# iustly:   	0.79%
# sir—o:   	0.75%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan twisted
# miscalld:   	50.79%
# reuels:   	15.17%
# gazeth:   	12.0%
# auld:   	4.8%
# enfeebled:   	4.7%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan twisted miscalld
# unmoved:   	28.06%
# twisted:   	23.85%
# franticmad:   	21.56%
# hotly:   	5.34%
# bell—diablo:   	5.17%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan twisted miscalld twisted
# reuels:   	35.38%
# miscalld:   	34.46%
# instruction:   	4.85%
# yew:   	4.51%
# enfeebled:   	4.02%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan twisted miscalld twisted yew
# franticmad:   	28.9%
# unmoved:   	21.35%
# now—whats:   	17.89%
# pontic:   	11.63%
# span:   	4.72%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan twisted miscalld twisted yew span
# isles:   	21.76%
# horned:   	18.13%
# shifted:   	15.19%
# unmoved:   	13.97%
# hotly:   	8.03%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name fear—how shifted instruction sir—o pontic reuels assassination scan twisted miscalld twisted miscalld unmoved miscalld twisted miscalld twisted iustly fear—how shifted gazeth returned returned dunnest isles scan twisted miscalld twisted yew span shifted
# miscalld:   	65.91%
# reuels:   	10.0%
# scan:   	7.72%
# instruction:   	5.85%
# gazeth:   	2.34%
# --------

# %% [markdown]
# This one almost seems readable and sounds like Shakespeare before the gibberish is thrown in at the end. We see miscalld and twisted repeated again but not as frequently. This one specifically doesn't have any 'normal' words. Most of them are all words you would see when reading Shakespeare, but none of them match anything in the original quote from Othello.
# > "If after every tempest come such calms,
# May the winds blow till they have wakened death,
# And let the laboring bark climb hills of seas
# Olympus-high, and duck again as low
# As hell's from heaven! If it were now to die,
# 'Twere now to be most happy, for I fear
# My soul hath her content so absolute
# That not another comfort like to this
# Succeeds in unknown fate."

# %%
info = text_generator.generate(
    "If after every tempest comes such calms", max_tokens=50, temperature=0.4
)
print_probs(info, vocab)
# Out:
# generated text:
# If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels gazeth now—whats franticmad isles miscalld twisted
#
#
# PROMPT: If after every tempest comes such calms
# twisted:   	99.63%
# unmoved:   	0.36%
# isles:   	0.01%
# returned:   	0.0%
# shifted:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted
# instruction:   	26.81%
# iustly:   	20.33%
# them—list:   	17.61%
# assassination:   	11.6%
# greeneyd:   	10.67%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd
# unmoved:   	98.28%
# twisted:   	1.36%
# franticmad:   	0.1%
# pontic:   	0.09%
# fear—how:   	0.05%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved
# scan:   	40.3%
# gazeth:   	39.82%
# iustly:   	5.67%
# them—list:   	3.53%
# tuggd:   	2.68%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd
# iustly:   	44.26%
# gazeth:   	32.61%
# instruction:   	18.94%
# assassination:   	3.65%
# miscalld:   	0.18%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly
# now—whats:   	22.48%
# franticmad:   	21.77%
# shifted:   	18.46%
# pontic:   	17.45%
# fear—how:   	13.6%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats
# returned:   	73.0%
# franticmad:   	10.88%
# horned:   	10.83%
# circled:   	4.36%
# shifted:   	0.62%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted
# miscalld:   	88.44%
# assassination:   	8.05%
# iustly:   	2.26%
# reuels:   	0.49%
# instruction:   	0.35%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination
# miscalld:   	99.88%
# gazeth:   	0.1%
# reuels:   	0.01%
# enfeebled:   	0.01%
# scan:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld
# twisted:   	99.69%
# unmoved:   	0.31%
# franticmad:   	0.0%
# iustly:   	0.0%
# span:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted
# miscalld:   	84.03%
# reuels:   	10.91%
# gazeth:   	4.95%
# enfeebled:   	0.06%
# scan:   	0.01%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld
# unmoved:   	69.15%
# twisted:   	24.98%
# franticmad:   	4.95%
# horned:   	0.32%
# hotly:   	0.18%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved
# miscalld:   	85.33%
# gazeth:   	8.85%
# reuels:   	5.51%
# scan:   	0.3%
# them—list:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld
# twisted:   	93.26%
# unmoved:   	5.8%
# franticmad:   	0.86%
# returned:   	0.04%
# hotly:   	0.01%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted
# reuels:   	84.91%
# gazeth:   	7.52%
# miscalld:   	7.32%
# enfeebled:   	0.22%
# iustly:   	0.01%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth
# returned:   	95.22%
# hotly:   	2.9%
# shifted:   	1.08%
# sir—o:   	0.36%
# franticmad:   	0.22%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned
# isles:   	80.87%
# returned:   	10.1%
# dunnest:   	2.95%
# pontic:   	2.02%
# horned:   	1.64%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles
# miscalld:   	50.95%
# scan:   	41.52%
# instruction:   	4.33%
# reuels:   	1.61%
# gazeth:   	0.94%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld
# twisted:   	89.3%
# unmoved:   	10.56%
# franticmad:   	0.14%
# horned:   	0.0%
# hotly:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted
# reuels:   	79.87%
# miscalld:   	11.64%
# gazeth:   	7.83%
# enfeebled:   	0.31%
# instruction:   	0.1%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels
# miscalld:   	92.64%
# enfeebled:   	3.66%
# gazeth:   	2.51%
# reuels:   	0.62%
# iustly:   	0.37%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled
# franticmad:   	90.23%
# unmoved:   	7.32%
# returned:   	1.22%
# sir—o:   	0.63%
# now—whats:   	0.2%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad
# horned:   	87.51%
# returned:   	9.96%
# sir—o:   	0.78%
# dunnest:   	0.49%
# hotly:   	0.46%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned
# shifted:   	48.4%
# unmoved:   	33.01%
# span:   	7.36%
# returned:   	3.95%
# chancd:   	2.7%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted
# miscalld:   	43.27%
# scan:   	37.06%
# gazeth:   	7.72%
# assassination:   	4.19%
# reuels:   	2.84%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld
# twisted:   	80.76%
# unmoved:   	19.15%
# franticmad:   	0.06%
# pontic:   	0.01%
# hotly:   	0.01%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted
# reuels:   	54.16%
# miscalld:   	32.15%
# gazeth:   	7.16%
# iustly:   	2.97%
# scan:   	1.28%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels
# miscalld:   	98.45%
# gazeth:   	0.91%
# enfeebled:   	0.39%
# iustly:   	0.15%
# instruction:   	0.03%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld
# unmoved:   	98.74%
# twisted:   	1.25%
# span:   	0.01%
# franticmad:   	0.0%
# pontic:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved
# miscalld:   	76.54%
# gazeth:   	21.82%
# reuels:   	0.94%
# scan:   	0.69%
# auld:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld
# twisted:   	84.38%
# unmoved:   	15.5%
# franticmad:   	0.07%
# pontic:   	0.01%
# hotly:   	0.01%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted
# gazeth:   	46.32%
# reuels:   	28.35%
# miscalld:   	16.43%
# iustly:   	5.36%
# instruction:   	1.68%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth
# returned:   	95.33%
# hotly:   	3.58%
# shifted:   	0.64%
# now—whats:   	0.19%
# sir—o:   	0.16%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned
# isles:   	82.49%
# returned:   	8.43%
# pontic:   	4.19%
# dunnest:   	3.17%
# hotly:   	0.87%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles
# miscalld:   	68.2%
# scan:   	27.52%
# gazeth:   	1.79%
# instruction:   	1.39%
# auld:   	0.46%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld
# twisted:   	97.02%
# unmoved:   	2.96%
# franticmad:   	0.02%
# hotly:   	0.0%
# span:   	0.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted
# reuels:   	41.86%
# miscalld:   	29.63%
# gazeth:   	22.55%
# iustly:   	1.83%
# enfeebled:   	1.34%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels
# miscalld:   	95.69%
# enfeebled:   	1.35%
# instruction:   	1.17%
# gazeth:   	0.99%
# iustly:   	0.41%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels gazeth
# returned:   	88.66%
# shifted:   	3.71%
# hotly:   	3.49%
# horned:   	1.35%
# now—whats:   	1.18%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels gazeth now—whats
# franticmad:   	61.55%
# returned:   	14.92%
# chancd:   	13.82%
# circled:   	2.89%
# shifted:   	2.62%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels gazeth now—whats franticmad
# returned:   	43.75%
# horned:   	26.96%
# isles:   	16.3%
# shifted:   	10.26%
# dunnest:   	1.87%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels gazeth now—whats franticmad isles
# miscalld:   	75.59%
# scan:   	19.73%
# instruction:   	3.73%
# assassination:   	0.42%
# gazeth:   	0.24%
# --------
#
#
# PROMPT: If after every tempest comes such calms twisted greeneyd unmoved tuggd iustly now—whats shifted assassination miscalld twisted miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels enfeebled franticmad horned shifted miscalld twisted reuels miscalld unmoved miscalld twisted gazeth returned isles miscalld twisted reuels gazeth now—whats franticmad isles miscalld
# twisted:   	92.31%
# unmoved:   	7.66%
# franticmad:   	0.03%
# horned:   	0.01%
# hotly:   	0.0%
# --------

# %% [markdown]
# ## 7. Build/Train the LSTM (Part 2: Multiple layers)

# %%
#I decided to try with 3 LSTM layers here because I heard of Google crashing or timing out with 4 LSTM layers
inputs2 = layers.Input(shape=(100,), dtype="int32")
x2 = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs2)
x2 = layers.LSTM(64, return_sequences=True)(x2)
x2 = layers.LSTM(128, return_sequences=True)(x2)
x2 = layers.LSTM(256)(x2)
outputs2 = layers.Dense(VOCAB_SIZE, activation="softmax")(x2)
lstm2 = models.Model(inputs2, outputs2)
lstm2.summary()
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)           │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding_6 (Embedding)              │ (None, 100, 100)            │       2,000,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_14 (LSTM)                       │ (None, 100, 64)             │          42,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_15 (LSTM)                       │ (None, 100, 128)            │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_16 (LSTM)                       │ (None, 256)                 │         394,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 20000)               │       5,140,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,675,296 (29.28 MB)
#  Trainable params: 7,675,296 (29.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
lstm2.compile("adam", loss_fn)

# %%
# Tokenize starting prompt

text_generator2 = TextGenerator(vocab)

# %%
lstm2.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[text_generator2],
)
# Out:
# Epoch 1/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.9241
# generated text:
# Out out brief candle i to the in and of it you the and a with that my the i be is your i and me in of a to a it to that my the so not of your the and is me the i and it in i to the that you be your to but a and a not my it is and the the to you i of that in to of and i your my it me be the and a the of i but to with is to not that and my in your
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 109s 32ms/step - loss: 6.9241
# Epoch 2/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.8166
# generated text:
# Out out brief candle and i of to i is you my with the the and me not a of it that a be thou my is you in this to for the not the the and a i a i of with of you is to to in that and the thou this not the a it my of of the for in you be and is to i that i the to not with this me the in my in be and the is and i for that not to of this a with the of it my
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 108s 32ms/step - loss: 6.8166
# Epoch 3/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7978
# generated text:
# Out out brief candle a that i the of not with it of in and the and you for to to is i me a not the my that this and with thou the for i in it is i you and and you be to of not my of the me a in it with i the the you this and to that i my and to not of of a it a i in this you with to that the and is me for and and but i you to it of of to not in a the
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 142s 32ms/step - loss: 6.7978
# Epoch 4/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7768
# generated text:
# Out out brief candle my i and the to a i in not to it is me with you his my of and of in a this the the a and is i to not with to my i and that be the of a the and the you in not i is to of a and and it my that of to i for with you the not a this in me i and and be in my it is for of and the of to to that the in the i with and a a for of i
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 142s 32ms/step - loss: 6.7768
# Epoch 5/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7968
# generated text:
# Out out brief candle i and to of a my not the the in you that to a it i be with and to me of for a the in thou not is of and but a i the and to be me i for of to with the in it is my you i not a and of and a for to to the the in it that of i you not is i of the a thou my the me and the with be in of for that is you it your a a i the of to
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 142s 32ms/step - loss: 6.7968
# Epoch 6/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7790
# generated text:
# Out out brief candle you my is not that the a it be of the the a to in i of and to for and my you the it me and is i to that this with you be a the a of i not to you the i my that it with and and the and this is you the not to of me of in my you that i the and i to the a not and with be this the it me and in that my of i a and to and the with this for it
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 141s 32ms/step - loss: 6.7790
# Epoch 7/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7801
# generated text:
# Out out brief candle that of and my and is with not the i in of me to a the you i and that of a and and be it for my is to i you the a in to of a the of and and that this for with not my you be a to and is it the and of of i the in to i you for my the a me and not this and of is the with that i to to i my the for it you and the in me in not you that
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 108s 32ms/step - loss: 6.7801
# Epoch 8/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7767
# generated text:
# Out out brief candle of my not and the i it to i that in is me to but the the and this as the for it you of of in a my i i but me and and the not that the it to and of with a is in i to the you but this the my and it and not and to i that for the i is in of the this but and to not my my i of you it me as with and and i this to the in for to the not i
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 200s 50ms/step - loss: 6.7767
# Epoch 9/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7805
# generated text:
# Out out brief candle of a is the not my it and i of and you and me to that in a this but is with the of to of for and and i not it that to this me in with the a my be to i is my but of i and that the to with me the you be not in the is to it of this and i the that but a the for with and i my the to of to this and in me not of i but for is you with my be
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 108s 32ms/step - loss: 6.7804
# Epoch 10/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7718
# generated text:
# Out out brief candle i in the and is i and you my the it the but of of thou i in a to with to me i not and a the it and of that i you the in to of the is for and and with me i to a that you be in i the the is not of it and for i thou and and me with a my you the the the of to is i for in to and not i a and me with my you you but the a i it in
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 142s 32ms/step - loss: 6.7718
# Epoch 11/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.7709
# generated text:
# Out out brief candle my a of the i the is i not you to it and but for a this in to that i be you i the the with me it and my but of not for a this the you in to i to the and and that i with of my of not is a it this the to i and and for you to the with that and is be but in this a of a to and me the to and not you it is my the i i but this a the in
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 110s 33ms/step - loss: 6.7709
# Epoch 12/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.7713
# generated text:
# Out out brief candle my the that me i a and to and with you in a not this in is the be of i i me the for and the of to with and in to my be that you and not is i for a of of a this it the i be and you in in and me that the a with a i for the my of of not you is in in this the that with it i for a and the of and me of my to not is you to a the i
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 141s 33ms/step - loss: 6.7713
# Epoch 13/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.7696
# generated text:
# Out out brief candle and the of i in and a to not is the i to of it this a with be me and that for you of and i a is the it and my in but to not i for a the with you that and of to the the and me it not i in a the i to that this is with my you in and to for it and of the a me that and to i this you of is not in i with a to of the that and a it for
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 110s 33ms/step - loss: 6.7696
# Epoch 14/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.7675
# generated text:
# Out out brief candle to of in i a is and you not of the with the this me to to a of and a is i in you that my the the not i the it of for to me of and to and with i is in the you but the it my for i to that of this not to and the in and with a it my is you to but i of the of i to not me the this and it is a you to that and i the of to in for of
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 141s 33ms/step - loss: 6.7675
# Epoch 15/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.7654
# generated text:
# Out out brief candle and a i to to with of in i it for and and the that the you and not to to my i in is the with it a and this be the and a i to not to my and in is but a of me this with thou it i be to i to that the and the a in me my of with you this the for of you not be thou a i in to is the me of that and with the and my it and i the you be to
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 143s 33ms/step - loss: 6.7654
# Epoch 16/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.7636
# generated text:
# Out out brief candle a is that the my to to and me i you and it not a with you i a in the the the is my but in that to i of not and i you me it to this and of the my the for a of you to i i me with that this to and it a is of my a the to you for the of i and i in this that with of it and the to the is a and of my but in a that and you for the this
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 140s 32ms/step - loss: 6.7636
# Epoch 17/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.7575
# generated text:
# Out out brief candle and the with thou the i with of your in this his the thy thou you a if and with be my and with me the the in the no i his thou to of this if you and and be thy a your the in the with me i his this no not and the my with thou thou the your in the me and if his this no you to as thy the of with with and your for me if the thou thou no to as the you thy not with in with
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 110s 33ms/step - loss: 6.7575
# Epoch 18/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.6897
# generated text:
# Out out brief candle i thou to you in the of your the as a and by with with your his not and in me you no i of to thou the and the as my his with by and the with not no me in of you and i thou this your the my and to with a his no your the of thou not and in by your i the the and you with as in to with thou no this of by the a in your and and you the your my i with as in this
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 141s 33ms/step - loss: 6.6897
# Epoch 19/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.6582
# generated text:
# Out out brief candle the in of with with the to as the and i thou you i his for your and this be in the the a to as with of thou not the by i and my his i this in be with for in the your of with you the by thou and my that i be his not i me as in with the you the thou of the and this with and be your for that as i with to you and in his my the not this thou with for of that your by
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 109s 33ms/step - loss: 6.6582
# Epoch 20/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.6764
# generated text:
# Out out brief candle to my i your thou the and you and with i for by of me be as a to my the not your his in the and with i thou you and of by for the i the this not me with my and i his you thou in and for of as the the not your be this i the with me thou a and to my i his for and of you be as the the me thou with with i this i his a your and the thy in as the to the
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 140s 32ms/step - loss: 6.6764
# Epoch 21/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.6536
# generated text:
# Out out brief candle of i the and thou your in the for you as my to and me not this no i of the of in and that your with a to and in the the me i as macbeth with this the of thou in your my of you that for no and me i the macbeth this as a it thou to and with in in the the and your i macbeth of me with this as of a my the to in not no and your i of me that this in as of it and
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 108s 32ms/step - loss: 6.6536
# Epoch 22/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.6704
# generated text:
# Out out brief candle thou as in the it and your with the of and this the i to thy thou no me thou in your a and that as the macbeth with the and of the it no thou my in in is thy me as the this your to i of the your a macbeth my and in in is and no it thy to the me the that thou your macbeth i thou in as of no your a and my thy is me the with the and this to thou of that you macbeth the as
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 142s 32ms/step - loss: 6.6704
# Epoch 23/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.6607
# generated text:
# Out out brief candle as the the in it of the a your thou that no me my by and as thy you and the of it with in thou your the to i in i and as a no my the this with and is thou by your of in in thou the as to i a it the thy and is with no my that by in your as you the thou of it and and is this a i that i in my your with no the to thou by in me this you it of the
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 107s 32ms/step - loss: 6.6607
# Epoch 24/25
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 6.6613
# generated text:
# Out out brief candle and thou in i this with the my the the is it of to that in you thou thou thy in as my your with the no and of is this it a and that in i to by as me the your and i in of thy the my you with and in no to it thou i me this the and is a your my with the in as in of thy no the i you me my and it a is your that the as the with this no in thou the my
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 108s 32ms/step - loss: 6.6613
# Epoch 25/25
# 3323/3324 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 6.6681
# generated text:
# Out out brief candle it the this the thou your my my in we and a the i by thy it as no the our i thou the with if thou that in your my the thy we in as the a of this it the thou no thou i my i if in thy your we the and my a the in thou as thou of this i that it my by your with the no if the the in thou a thy we i that i in by this thou my as the the your in of my
#
# 3324/3324 ━━━━━━━━━━━━━━━━━━━━ 107s 32ms/step - loss: 6.6681

# %% [markdown]
# The thing that is really interesting about the 3-layer model is that it basically only uses the most common words whereas the single layer model used very obsure words and often avoided the most common ones. All of the epochs tend to use 'i, you, thou' quite frequently. None of these are coherent either. I am unsure why this one and the previous one are so different with word choices.This one is hard to read as there is a lot of repetition of consecutive pronouns. Varying the number of units in each LSTM layer creates a hierarchical learning structure for the model. I think I may have started too small and created a bottleneck issue. That could be why mainly the simplest words were always used. Smaller units are faster and won't overfit, but won't generate as high quality text. For a larger dataset like this one, I should have gone with higher numbers.

# %% [markdown]
# ## 8. Generate text using the Multi-Layer LSTM

# %% [markdown]
# Looking at the percentages, it looks like the only possibilities are the most common words. The percentages are also very low for each one. Even though this one is short, it does not make sense at all and actually seems worse than the first one.
# > "By the pricking of my thumbs something wicked this way comes"

# %%
info = text_generator2.generate(
    "By the pricking of my thumbs", max_tokens=10, temperature=0.5
)
print_probs(info, vocab)
# Out:
# generated text:
# By the pricking of my thumbs i the with your
#
#
# PROMPT: By the pricking of my thumbs
# the:   	32.48%
# thou:   	17.59%
# in:   	10.61%
# i:   	9.39%
# as:   	6.28%
# --------
#
#
# PROMPT: By the pricking of my thumbs i
# the:   	34.09%
# thou:   	18.51%
# in:   	11.21%
# as:   	6.67%
# your:   	5.75%
# --------
#
#
# PROMPT: By the pricking of my thumbs i the
# thou:   	25.02%
# in:   	15.01%
# the:   	11.45%
# as:   	8.92%
# your:   	7.74%
# --------
#
#
# PROMPT: By the pricking of my thumbs i the with
# thou:   	25.52%
# in:   	15.15%
# the:   	11.6%
# as:   	8.94%
# your:   	7.56%
# --------

# %% [markdown]
# Somehow, with all of the common words being used, none of them match up with the actual quote. There is really not much to say about this one other than the fact that it doesn't make sense. I can see the the low temperature is somewhat trying with 'thou in i with my.' It rhymes and is somewhat readable.
# > "But, soft! what light through yonder window breaks?
# It is the east, and Juliet is the sun."

# %%
info = text_generator2.generate(
    "What light through yonder window breaks", max_tokens=20, temperature=0.2
)
print_probs(info, vocab)
# Out:
# generated text:
# What light through yonder window breaks the the thou in i with my the this in thou a and your
#
#
# PROMPT: What light through yonder window breaks
# the:   	98.59%
# thou:   	0.67%
# my:   	0.27%
# in:   	0.19%
# i:   	0.14%
# --------
#
#
# PROMPT: What light through yonder window breaks the
# the:   	67.84%
# thou:   	15.29%
# my:   	5.99%
# in:   	4.23%
# i:   	3.1%
# --------
#
#
# PROMPT: What light through yonder window breaks the the
# thou:   	45.44%
# my:   	17.39%
# in:   	12.13%
# i:   	8.77%
# the:   	6.1%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou
# my:   	31.22%
# in:   	21.62%
# i:   	15.73%
# the:   	10.93%
# as:   	5.85%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in
# my:   	38.57%
# i:   	19.77%
# the:   	13.35%
# as:   	7.31%
# your:   	4.91%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i
# my:   	46.04%
# the:   	16.21%
# as:   	8.97%
# your:   	6.3%
# it:   	4.85%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with
# my:   	46.07%
# the:   	17.35%
# as:   	8.74%
# your:   	6.07%
# it:   	4.84%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with my
# the:   	30.07%
# as:   	15.92%
# your:   	10.91%
# it:   	8.95%
# this:   	7.64%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with my the
# as:   	22.32%
# your:   	15.21%
# it:   	12.18%
# this:   	10.46%
# thou:   	9.39%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with my the this
# as:   	24.31%
# your:   	16.04%
# it:   	13.3%
# thou:   	10.45%
# and:   	9.56%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with my the this in
# as:   	24.38%
# your:   	16.35%
# it:   	13.47%
# thou:   	10.09%
# and:   	9.92%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with my the this in thou
# as:   	26.42%
# your:   	18.06%
# it:   	14.58%
# and:   	10.59%
# we:   	10.0%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with my the this in thou a
# as:   	26.97%
# your:   	18.58%
# it:   	14.92%
# and:   	11.03%
# we:   	9.99%
# --------
#
#
# PROMPT: What light through yonder window breaks the the thou in i with my the this in thou a and
# as:   	29.81%
# your:   	20.43%
# it:   	16.47%
# we:   	11.11%
# that:   	8.13%
# --------

# %% [markdown]
# This one hurts to read. It seems too random and not coherent in the slightest due to the high temp. The percents are very close to each other here, so it would seem to be even more random.
# > "Deny thy father and refuse thy name. Or, if thou wilt not, be but sworn my love, And I'll no longer be a Capulet."

# %%
info = text_generator2.generate(
    "Deny thy father and refuse thy name", max_tokens=40, temperature=1.0
)
print_probs(info, vocab)
# Out:
# generated text:
# Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my that in the my with thou a
#
#
# PROMPT: Deny thy father and refuse thy name
# the:   	31.01%
# thou:   	11.46%
# my:   	9.55%
# in:   	8.89%
# i:   	8.38%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the
# the:   	18.28%
# thou:   	13.57%
# my:   	11.27%
# in:   	10.51%
# i:   	9.88%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as
# the:   	18.68%
# thou:   	13.85%
# my:   	11.45%
# in:   	10.66%
# i:   	9.99%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it
# the:   	18.71%
# thou:   	13.94%
# my:   	11.57%
# in:   	10.78%
# i:   	10.13%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your
# the:   	19.16%
# thou:   	14.26%
# my:   	11.79%
# in:   	10.97%
# i:   	10.29%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i
# the:   	20.17%
# thou:   	14.93%
# my:   	12.45%
# in:   	11.56%
# this:   	7.66%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that
# the:   	20.57%
# thou:   	15.13%
# my:   	12.6%
# in:   	11.74%
# this:   	7.76%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in
# the:   	21.78%
# thou:   	16.04%
# my:   	13.4%
# this:   	8.26%
# with:   	7.9%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my
# the:   	23.36%
# thou:   	17.21%
# this:   	8.85%
# with:   	8.47%
# we:   	8.46%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a
# the:   	23.62%
# thou:   	17.38%
# this:   	8.95%
# with:   	8.56%
# we:   	8.53%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the
# thou:   	19.78%
# the:   	13.35%
# this:   	10.14%
# we:   	9.72%
# with:   	9.69%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with
# thou:   	20.5%
# the:   	13.81%
# this:   	10.43%
# we:   	9.95%
# my:   	8.49%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou
# the:   	14.76%
# this:   	11.23%
# thou:   	10.98%
# and:   	10.95%
# we:   	10.68%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this
# the:   	15.4%
# thou:   	11.42%
# and:   	11.3%
# we:   	11.18%
# my:   	9.47%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i
# the:   	15.47%
# thou:   	11.41%
# and:   	11.38%
# we:   	11.24%
# my:   	9.54%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and
# the:   	16.16%
# thou:   	11.84%
# we:   	11.7%
# my:   	9.89%
# in:   	9.21%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we
# the:   	28.66%
# thou:   	10.6%
# my:   	8.78%
# in:   	8.2%
# by:   	7.77%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou
# the:   	28.02%
# as:   	12.36%
# my:   	8.65%
# in:   	8.04%
# by:   	7.64%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our
# the:   	26.79%
# as:   	11.91%
# it:   	10.55%
# my:   	8.29%
# in:   	7.71%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the
# the:   	14.83%
# as:   	13.12%
# your:   	12.11%
# it:   	11.6%
# my:   	9.13%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as
# the:   	15.66%
# your:   	12.7%
# it:   	12.24%
# my:   	9.64%
# in:   	8.96%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy
# the:   	15.2%
# your:   	12.34%
# it:   	11.92%
# that:   	10.39%
# my:   	9.38%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of
# in:   	16.02%
# the:   	13.98%
# your:   	11.39%
# it:   	10.97%
# that:   	9.54%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it
# my:   	16.44%
# in:   	15.33%
# the:   	13.36%
# your:   	11.05%
# that:   	9.09%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in
# my:   	17.54%
# the:   	14.35%
# your:   	11.64%
# that:   	9.67%
# a:   	8.71%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the
# my:   	17.52%
# the:   	14.2%
# your:   	11.65%
# that:   	9.72%
# a:   	8.75%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my
# the:   	15.1%
# your:   	12.29%
# with:   	10.93%
# that:   	10.28%
# my:   	9.3%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my that
# the:   	14.94%
# your:   	12.17%
# thou:   	11.08%
# with:   	10.83%
# my:   	9.22%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my that in
# the:   	14.54%
# your:   	11.9%
# this:   	11.02%
# thou:   	10.73%
# with:   	10.54%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my that in the
# i:   	15.57%
# your:   	11.91%
# this:   	10.98%
# thou:   	10.67%
# with:   	10.49%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my that in the my
# i:   	15.32%
# your:   	11.59%
# this:   	10.79%
# thou:   	10.56%
# and:   	10.46%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my that in the my with
# i:   	15.35%
# your:   	11.53%
# this:   	10.78%
# thou:   	10.57%
# and:   	10.52%
# --------
#
#
# PROMPT: Deny thy father and refuse thy name the as it your i that in my a the with thou this i and we thou our the as thy of it in the my that in the my with thou
# i:   	15.32%
# your:   	11.59%
# this:   	10.77%
# thou:   	10.54%
# and:   	10.47%
# --------

# %% [markdown]
# This one gave me hope after the first few words, but completely fell apart. I feel like a better model using 0.4-0.5 for temperature will be the sweet spot as I have noticed they have been the best for these tests.There is still too much repetition and nearly no variety in words like all of the other ones generated by the second lstm model.
# > "If after every tempest come such calms, May the winds blow till they have wakened death, And let the laboring bark climb hills of seas Olympus-high, and duck again as low As hell's from heaven! If it were now to die, 'Twere now to be most happy, for I fear My soul hath her content so absolute That not another comfort like to this Succeeds in unknown fate."

# %%
info = text_generator2.generate(
    "If after every tempest comes such calms", max_tokens=50, temperature=0.4
)
print_probs(info, vocab)
# Out:
# generated text:
# If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your in i in the with thy my
#
#
# PROMPT: If after every tempest comes such calms
# the:   	76.49%
# thou:   	6.42%
# my:   	4.04%
# in:   	3.36%
# i:   	2.88%
# --------
#
#
# PROMPT: If after every tempest comes such calms the
# the:   	36.48%
# thou:   	17.41%
# my:   	10.86%
# in:   	9.09%
# i:   	7.76%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and
# the:   	36.67%
# thou:   	17.34%
# my:   	10.9%
# in:   	9.08%
# i:   	7.77%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou
# the:   	42.75%
# my:   	12.69%
# in:   	10.62%
# i:   	9.11%
# as:   	5.51%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with
# the:   	42.78%
# my:   	12.7%
# in:   	10.61%
# i:   	9.11%
# as:   	5.51%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the
# my:   	19.49%
# in:   	16.36%
# i:   	14.01%
# the:   	11.55%
# as:   	8.55%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we
# my:   	19.72%
# in:   	16.5%
# i:   	13.97%
# the:   	11.82%
# as:   	8.61%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the
# my:   	21.58%
# in:   	17.98%
# i:   	15.31%
# as:   	9.37%
# your:   	7.61%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as
# my:   	23.13%
# in:   	19.22%
# i:   	16.4%
# your:   	8.14%
# it:   	7.43%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this
# my:   	24.06%
# in:   	20.04%
# i:   	17.18%
# your:   	8.55%
# it:   	7.77%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no
# my:   	24.07%
# in:   	20.13%
# i:   	17.24%
# your:   	8.62%
# it:   	7.78%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i
# my:   	28.07%
# in:   	23.36%
# your:   	10.22%
# it:   	9.09%
# thou:   	7.76%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a
# my:   	28.59%
# in:   	23.93%
# your:   	10.44%
# it:   	9.26%
# thou:   	7.91%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it
# my:   	30.34%
# in:   	25.59%
# your:   	11.14%
# thou:   	8.45%
# that:   	6.92%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your
# my:   	33.03%
# in:   	27.7%
# thou:   	9.35%
# that:   	7.5%
# by:   	4.29%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the
# my:   	33.06%
# in:   	27.62%
# thou:   	9.42%
# that:   	7.53%
# by:   	4.33%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in
# my:   	42.87%
# thou:   	12.12%
# that:   	9.72%
# in:   	6.3%
# by:   	5.56%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in
# my:   	40.61%
# thou:   	11.32%
# and:   	11.22%
# that:   	9.25%
# by:   	5.27%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my
# thou:   	53.65%
# and:   	9.43%
# that:   	7.73%
# my:   	6.02%
# by:   	4.42%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou
# thou:   	15.53%
# and:   	15.4%
# with:   	14.76%
# that:   	12.62%
# my:   	9.79%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy
# the:   	25.87%
# thou:   	12.33%
# and:   	12.12%
# with:   	11.6%
# that:   	9.98%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with
# the:   	25.88%
# thou:   	12.36%
# and:   	12.1%
# we:   	11.47%
# that:   	10.0%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if
# the:   	66.39%
# thou:   	5.59%
# and:   	5.45%
# we:   	5.31%
# that:   	4.51%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the
# the:   	22.76%
# as:   	16.66%
# thou:   	10.82%
# and:   	10.37%
# we:   	10.29%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we
# the:   	22.44%
# as:   	16.39%
# this:   	11.22%
# thou:   	10.83%
# and:   	10.29%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i
# the:   	22.17%
# as:   	16.6%
# this:   	11.27%
# thou:   	10.66%
# and:   	10.45%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and
# the:   	23.98%
# as:   	17.58%
# this:   	11.91%
# thou:   	11.19%
# that:   	9.05%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as
# the:   	26.95%
# this:   	13.34%
# thou:   	12.44%
# that:   	10.12%
# my:   	7.87%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a
# the:   	24.96%
# it:   	13.59%
# this:   	12.54%
# thou:   	11.64%
# that:   	9.61%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by
# the:   	22.81%
# your:   	13.73%
# it:   	12.38%
# this:   	11.41%
# thou:   	10.77%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it
# the:   	65.0%
# your:   	7.06%
# this:   	5.81%
# thou:   	5.45%
# that:   	4.41%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that
# the:   	66.52%
# your:   	6.95%
# this:   	5.82%
# thou:   	5.55%
# my:   	3.48%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the
# in:   	27.91%
# the:   	19.65%
# your:   	12.0%
# this:   	9.98%
# thou:   	9.41%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my
# in:   	27.88%
# the:   	19.94%
# your:   	11.9%
# this:   	9.92%
# thou:   	9.45%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the
# thou:   	41.77%
# in:   	21.84%
# your:   	9.4%
# this:   	7.8%
# my:   	4.61%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou
# in:   	33.33%
# your:   	14.09%
# this:   	11.83%
# thou:   	11.34%
# my:   	7.06%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your
# in:   	34.48%
# this:   	12.33%
# thou:   	11.6%
# with:   	11.03%
# my:   	7.29%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your in
# this:   	17.2%
# thou:   	16.28%
# with:   	15.31%
# my:   	10.23%
# in:   	8.54%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your in i
# the:   	26.93%
# this:   	13.61%
# thou:   	12.58%
# with:   	12.17%
# my:   	8.06%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your in i in
# the:   	25.99%
# this:   	12.84%
# thou:   	11.94%
# we:   	11.61%
# with:   	11.44%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your in i in the
# this:   	16.18%
# thou:   	15.04%
# we:   	14.49%
# with:   	14.44%
# my:   	9.47%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your in i in the with
# this:   	15.97%
# thou:   	15.34%
# and:   	14.82%
# we:   	14.16%
# my:   	9.56%
# --------
#
#
# PROMPT: If after every tempest comes such calms the and thou with the we the as this no i a it your the in in my thou thy with if the we i and as a by it that the my the thou your in i in the with thy
# as:   	19.86%
# this:   	13.58%
# thou:   	12.96%
# and:   	12.71%
# we:   	11.96%
# --------

# %% [markdown]
# ##Conclusion
#
# > I was honestly disappointed when reading the text that was generated after spending quite some time working on this assignment over the past week. When I originally generated text, I ran into the issue of punctuation being repeated like normal words. In Shakespeare, there are a lot of apostrophes and dashes and colons. The line breaks are also different because most of the texts I used were plays and there would be a character name, a colon, and a sentence. After trying to deal with them, I couldn't really find a good solution, so I removed punctuation altogether. After attempt 1, everything looked good. Then, I got to the text generation and "overthrow" was being repeated like 10-20 times in a row on each prompt. So I went back to the drawing board and focused lots of time on the TextGenerator. Some edits got me closer and some pushed me farther away from a good solution. After hours of trying to fix this, I reverted to the one that gave the best results for the first LSTM. I am thankful that I was able to stay connected to my runtime for the entire time I was testing and debugging. The second LSTM model took around an hour to run and might honestly be worse than the first model that took 20 mins to run. Unfortunately, there was a big disconnect between the 2 models and each was missing something the other had. As much as I would love to spend 15 hours fixing my models and training them again, I unfortunately cannot and had to settle with what I generated here.

# %% [markdown]
# ##Reference:
# * https://github.com/bforoura/GenAI/blob/main/Module5/recipe_lstm.ipynb
